# %%
import rasterio
from rasterio.plot import show
from PIL import Image
img = Image.open("D:\work images\HH-ALPSRP244140480-H2.2_UA.tif")
show(img)
pixels = img.load()

# %%
import rasterio
with rasterio.open("D:\work images\HH-ALPSRP244140480-H2.2_UA.tif") as dataset:
    width = dataset.width
    height = dataset.height
    print("Image Size (Width x Height):", width, "x", height)
    num_bands = dataset.count
    print("Number of Bands:", num_bands)
# Out:
# Image Size (Width x Height): 5700 x 4700
# Number of Bands: 1

# %%
dataset.count
dataset.width
dataset.height
# Out:
# 4700

# %%
import numpy as np
from PIL import Image
img = Image.open("D:\\work images\\HH-ALPSRP244140480-H2.2_UA.tif")
img_array = np.array(img)
mean = np.mean(img_array)
std_dev = np.std(img_array)
min = np.min(img_array)
max = np.max(img_array)
print("Mean:", mean)
print("Standard Deviation:", std_dev)
print("Min:", min)
print("Max:", max)
# Out:
# Mean: 2229.4633836132884
# Standard Deviation: 2965.282871694475
# Min: 0
# Max: 65535

# %%
import matplotlib.pyplot as plt
import cv2

try:
    img = cv2.imread("D:\work images\HH-ALPSRP244140480-H2.2_UA.tif") 
    (height, width) = img.shape[:2]    
    res = cv2.resize(img, (int(width / 4), int(height / 4)), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite('result.tiff', res)
    plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))  # Convert color channels for Matplotlib
    plt.show()
 
except IOError:
    print('Error while reading files !!!')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

M = np.float32([[1, 0, 200], [0, 1, 200]])

try:
    img = cv2.imread("D:\work images\HH-ALPSRP244140480-H2.2_UA.tif")
    rows, cols = img.shape[:2]
    
    res2 = cv2.warpAffine(img, M, (cols, rows))
    cv2.imwrite('result_shifted.tiff', res2)
    
    plt.imshow(cv2.cvtColor(res2, cv2.COLOR_BGR2RGB))  # Convert color channels for Matplotlib
    plt.show()

except IOError:
    print('Error while reading files !!!')

# %%
import cv2
import matplotlib.pyplot as plt

try:
    img = cv2.imread("D:\work images\HH-ALPSRP244140480-H2.2_UA.tif")
    edges = cv2.Canny(img, 50, 100)
    cv2.imwrite('result_edges.tiff', edges)
    
    plt.imshow(edges, cmap='gray')  # Display the edges in grayscale
    plt.show()

except IOError:
    print('Error while reading files !!!')

# %%
#Converting into RGB
import cv2
import matplotlib.pyplot as plt
try:
    img2 = cv2.imread("D:\work images\HH-ALPSRP244140480-H2.2_UA.tif")
    img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
    plt.imshow(img2_rgb)
except IOError:
    print('Error while reading files !!!')
